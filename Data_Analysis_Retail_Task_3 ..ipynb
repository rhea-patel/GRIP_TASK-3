# %% [markdown]
# # The Sparks Foundation **#task3**
#
# Data Science and Business Analytics
#
# Riya R. Patel

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')
print("All Module Imported!!")
# Out:
# All Module Imported!!

# %%
df=pd.read_csv("/content/drive/MyDrive/SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
# Basic Insights of data

# %%
df.sample(5)
# Out:
#            Ship Mode      Segment        Country  ... Quantity Discount    Profit
# 4990  Standard Class  Home Office  United States  ...        4      0.2   77.5584
# 5658     First Class  Home Office  United States  ...        5      0.5 -264.2150
# 7237        Same Day    Corporate  United States  ...        3      0.7 -319.1916
# 3682  Standard Class     Consumer  United States  ...        4      0.0   32.5376
# 5906        Same Day  Home Office  United States  ...        1      0.0    1.0170
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <bound method DataFrame.info of            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# [9994 rows x 13 columns]>

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Unique Values

# %%
for i in df.columns:
  print(i,len(df[i].unique()))
# Out:
# Ship Mode 4
# Segment 3
# Country 1
# City 531
# State 49
# Postal Code 631
# Region 4
# Category 3
# Sub-Category 17
# Sales 5825
# Quantity 14
# Discount 12
# Profit 7287

# %% [markdown]
# Null Values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Visualization tasks

# %%
sns.pairplot(df)

# %%
fig,axes=plt.subplots(1,1,figsize=(12,7))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# Total Profit vs Sales

# %%
fig,axes=plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Total profit vs sales")
sns.barplot(data=df.groupby('Sub-Category')['Sales','Profit'].agg(sum),x='Sales',y='Profit',ax=axes[1])
df.groupby('Sub-Category')['Sales','Profit'].agg(sum).plot(kind='bar',ax=axes[0])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Total Sales vs Quantity

# %%
fig,axes=plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Total Sales vs Quantity")
sns.barplot(data=df.groupby('Sub-Category')['Sales','Quantity'].agg(sum),x='Sales',y='Quantity',ax=axes[1])
df.groupby('Sub-Category')['Sales','Quantity'].agg(sum).plot(kind='bar',ax=axes[0])
plt.xticks(rotation=90)
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(14,5))
df.groupby('Sub-Category')['Sales','Quantity'].agg(sum).plot(kind='bar',ax=axes[0]).set_title('Dis&pro based on sub-cate.')
df.groupby('Sub-Category')['Sales','Quantity'].agg(sum).plot(kind='bar',ax=axes[1]).set_title('Quan&pro based on sub-cate.')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Distribution Plots

# %%
fig,axes=plt.subplots(2,2,figsize=(16,8))
fig.suptitle("Distribution plots",fontsize=16)
sns.distplot(df['Sales'],ax=axes[0,0])
sns.distplot(df['Profit'],ax=axes[0,1])
sns.distplot(df['Discount'],ax=axes[1,0])
sns.distplot(df['Quantity'],ax=axes[1,1])
plt.show()

# %% [markdown]
# Sales with diff shipping modes and Segments

# %%
fig,axes=plt.subplots(2,2,figsize=(16,8))
fig.suptitle("Sales with diff shipping modes and Segments",fontsize=16)
sns.barplot(df['Ship Mode'],df['Sales'],ax=axes[0,0])
sns.lineplot(df['Ship Mode'],df['Sales'],ax=axes[0,1])
sns.barplot(df['Segment'],df['Sales'],ax=axes[1,0])
sns.lineplot(df['Ship Mode'],df['Sales'],ax=axes[1,1])
plt.show()

# %%
fig,ax=plt.subplots(1,1,figsize=(12,7))
sns.countplot(df['Quantity'],hue=df['Region'])
plt.show()

# %% [markdown]
# # **Some important Findings**
#
#
# *   Profit and Discount are highly rated.
# *   Made of shipping doesn't affect the sales.
# *   Sales are high of less Quantity
# *   Home office provides highest sales followed by slight variation.
# *   Maximum demanded Quantity was in range of 2-4.
